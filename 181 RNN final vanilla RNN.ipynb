# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# #### Prepare for Dataset

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('./shakespeare.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 1115394
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Get a random sequence of the Shakespeare dataset.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        
        self.rnn = nn.RNNCell(self.input_size, self.hidden_size)
        self.linear = nn.Linear(self.hidden_size, self.output_size)
        ###### To be filled ######
        ###### To be filled ######
    
    def forward(self, input, hidden):
        """ Forward function.
              input:  One-hot input. It refers to the x_t in homework write-up.
              hidden: Previous hidden state. It refers to the h_{t-1}.
            Returns (output, hidden) where output refers to y_t and 
                     hidden refers to h_t.
        """
        # Forward function.
        hidden = self.rnn(input,hidden)###### To be filled ######
        output =self.linear(hidden) ###### To be filled ######

        return output, hidden

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(1, self.hidden_size).to(device) 
    
net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (rnn): RNNCell(100, 100)
#   (linear): Linear(in_features=100, out_features=100, bias=True)
# )

# %% [markdown]
# #### Training Step and Evaluation Step

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# #### Training Procedure

# %%
# Number of iterations.
iters       = 15000  # Number of training iterations.
print_iters = 100    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.Adam(net.parameters(), lr=0.005)
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:99/15000 loss:3.323991298675537
# generated sequence: WB.ns:enefR, ooMyeth fhrlthmvet
# one;nase imnoI:acl at:tmtsp: hio io aIuaR nIwdmwn ao t en'e th lh tsi
#
# iter:199/15000 loss:2.8346850872039795
# generated sequence: WLir!
# .nUy wewd, eip hodime win', yost mand dim; car  whem.
# ILle te lfwOGWe, honterit mith, in fedan
#
# iter:299/15000 loss:2.5291764736175537
# generated sequence: Why munas.
# he pat  hey
# to dot draru.
#
# KCETAEI-me dongand Tit, Indeng mytl, brou ma dr timd, beosd be
#
# iter:399/15000 loss:2.4193685054779053
# generated sequence: Wit eoreregamy, wyoas bozed dheawistatr lour llo withot ruld shound or wende, gllli heee, me nis grom
#
# iter:499/15000 loss:2.356175422668457
# generated sequence: Werurur eatith I ley!dy.
#
# QUKINNTCAMENINEd COLDYCHUOGRKE:
# I ate thome, dolr at; lurayo tho cestile an
#
# iter:599/15000 loss:2.3110744953155518
# generated sequence: Wede.
#
# LAUCE:
# Thas darthed me dime in dor ufen.
#
# LSKAOd that u<gove hears nove by o ke cim wime thal
#
# iter:699/15000 loss:2.2363803386688232
# generated sequence: Wh velowhiven.
# And foredir eumeiowh cith
# Vendeis is I am
# Heen
# Bit toos. My, nothhor methert noos meiv
#
# iter:799/15000 loss:2.2167210578918457
# generated sequence: Wile hy ferd'dreed at 'f rot me Kl homoweres sde have in,
# Se's gry stirgst.
#
# BAMFMIFI:
# For king, s yo
#
# iter:899/15000 loss:2.201279878616333
# generated sequence: Will ractofo, waweld, whas ceremert sind II at; loZs,
# And weRT, be winderuth stonnelld yout.
# Dice and
#
# iter:999/15000 loss:2.164608955383301
# generated sequence: Wholl hive menceads verbeyan, thy now phen to to tays n belengbe to you keald I'Llumered; I' Duythr:
#
# iter:1099/15000 loss:2.1688146591186523
# generated sequence: Wad net  ich orseds
# The cested Vor,
# And enese:
# What Rormew thes you fread ertud ars bestenter comethe
#
# iter:1199/15000 loss:2.1136512756347656
# generated sequence: We thromyol to aponlis leco som our trer tid tis is anbs, as II dadely fery carith's, at is a gribe H
#
# iter:1299/15000 loss:2.107367753982544
# generated sequence: Weant thiclle:
# Thenchen somak mare mond whelt.
#
# BI
# ASDO:
# Mank to inke to that
# our by,
# By wor she ther
#
# iter:1399/15000 loss:2.097615957260132
# generated sequence: Wh
# Khouldid-gitles theoyolds
# Forses?
# Shire, chonglute, yat; thofen a giten's duhf.
#
# ESTERSTO:
# Ord, no
#
# iter:1499/15000 loss:2.0830271244049072
# generated sequence: WARD IA:
# Son maor my a couse, mire the daye hatser aince.
#
# JUKENEE:
# Noy I novan, tor bigemy bee f you
#
# iter:1599/15000 loss:2.079881429672241
# generated sequence: WEuld for vead, dich. Whele toot?
#
# SOLK:
# Thus my band:
# I keen duke mond dainthime.
#
# LUCEn:
# Gored leve
#
# iter:1699/15000 loss:2.0765786170959473
# generated sequence: Will bcheng the gongs tee frupes youbmy cord in deod the wisce
# sir, my lard is vis king mobel
# Whis bu
#
# iter:1799/15000 loss:2.0480008125305176
# generated sequence: WIRd:
# Weat fithte son the casseightscled ther: dorking at scould not mfarest havithertake ward lass,
#
#
# iter:1899/15000 loss:2.0921199321746826
# generated sequence: Whind:
# Weall coos of a the aze not
# That and! best dy, wha GfortI in reanther maid wirt barmy wang you
#
# iter:1999/15000 loss:2.0221188068389893
# generated sequence: WARD gho guich; precong cord: one ale praicofes
# Towe mances?
#
# MAPULLAUD:
# Mowesby it wime farthy now F
#
# iter:2099/15000 loss:2.047260284423828
# generated sequence: We'll is thee a vely,
# An mastse-deed, trut finds meptereal yovy?
#
# KING,
# MAMINA:
# And I me gakn'd she s
#
# iter:2199/15000 loss:2.007740020751953
# generated sequence: WARD IV:
#
# MORTENIO:
# O, monelit hight,-fo,
# There is aw is and mumet an entorse,
# Thas you is a gang,
# Wh
#
# iter:2299/15000 loss:2.0074477195739746
# generated sequence: WhRin,
# Shy reconants
# Ap my heart'er tyatle four vaoner all'd my midisernecaneth dowore,
# For art,
# Nout
#
# iter:2399/15000 loss:2.013258934020996
# generated sequence: WICA IS:
# The wick dikisealdrust to with wach heech,
# O wreeen say,
# So with ear that fis to out, that s
#
# iter:2499/15000 loss:1.9310364723205566
# generated sequence: WAlas'.
#
# LOUT:
# The kee'geowfores thrye Fit myem-one tor' time?
# The pestre eseen.
# Ig thene herernove.
#
#
# iter:2599/15000 loss:1.9687445163726807
# generated sequence: Whee for but thy Cos reemo:
#
# BETTHNANT:
# Yee this as I mo hell whe moress I makeer.
#
# JOLINA:
# Somanio!
#
#
# iter:2699/15000 loss:2.011162042617798
# generated sequence: Whim.
#
# SICHARD II:
# Seven
# broud from
# Or hom. Willo: tenn to
# duiesel
#
# POULO,
# TRO:
# Or.
# GLLOUven:
# Whance
#
# iter:2799/15000 loss:1.9718197584152222
# generated sequence: We are
# Levirnh agppathing
# Tham I now thair.
#
# KENG OF EINCES
# But ono faight anken these courh Glith! h
#
# iter:2899/15000 loss:1.961823582649231
# generated sequence: Whe king's mease oin dalbour
# From nove, nor ngabu with spartles nam kell broigh
# Ald dovingr like your
#
# iter:2999/15000 loss:1.996160864830017
# generated sequence: Wile hhare our vucknil; chopy bott like.
# Sometrounder booked
# Sory gamman chard dich a bay
# I' the echi
#
# iter:3099/15000 loss:1.9439727067947388
# generated sequence: Whin, eastiest
# Com
# Whace with this hersied wiot me and buch sake in Isentwert' brath whr vingamly
# Tha
#
# iter:3199/15000 loss:1.9609284400939941
# generated sequence: Withresets is ever to our mather thought
# Prucouseecless.
#
# for XENCEONCHIUSHARHAPNCANUS:
# But I thing t
#
# iter:3299/15000 loss:1.9898046255111694
# generated sequence: Whoun; my gever ift lawe to dy nappanger:
# Hithfrand no wilmone, What I wouldy tent with-us earing pif
#
# iter:3399/15000 loss:1.9554669857025146
# generated sequence: Why knownated whope of with be
# Kith the knishur oltosm comiof?
#
# GLANIET:
# Ascomperve well non
# ine and
#
# iter:3499/15000 loss:1.9269750118255615
# generated sequence: Whonges, brengeaces agade brother.
#
# GRUMCO:
# Your crisels, Bithiok us,
# I forfagityeic
# Fitho
# PEdase mus
#
# iter:3599/15000 loss:1.9546695947647095
# generated sequence: WARD CINGARD:
# I, iothy I'up with siture
# And tor atthis landy.
# Thankagbyse you love gaith, how, whom d
#
# iter:3699/15000 loss:1.933931827545166
# generated sequence: WIRk IO!
# She my bonds boven owarr mecanned my wigh,
# Now not my paid,
# And me:
# Do more?
#
# HENRY BARD:
# Si
#
# iter:3799/15000 loss:1.9466166496276855
# generated sequence: Why, ot misbues, thyes!
# Hers this with sigstruher.
#
# POLYCA:
# On's
# RINCANIO:
#
# Pary swise and you this
# D
#
# iter:3899/15000 loss:1.946421504020691
# generated sequence: WARD It:
# Ray, the ray your'd jusping truees' rost missons.
#
# PETRUCHIO:
# Faven all derear'd it and and
#
# iter:3999/15000 loss:1.9507462978363037
# generated sequence: What you's by haplided word:
# To-f;
# And, eveng--A fare sucueses are gropbess.
#
# BERGNUS:
# Les for knom I
#
# iter:4099/15000 loss:1.9374085664749146
# generated sequence: Why sponie's dead live the was us dough
# ch though has sigloly momine lises, 'Awill dube wide, a goado
#
# iter:4199/15000 loss:1.927287220954895
# generated sequence: WIRDATIO:
# Tream-pay's baistare the fories,
# But we musce, bet
# an foors apparti'd no aps.
# Or was sitson
#
# iter:4299/15000 loss:1.926525354385376
# generated sequence: Who grime; of lood linn.
# On, couldsest Iver madice?
#
# Second Me, my listabe
# Eoverve
# to entoud, and it
#
# iter:4399/15000 loss:1.916163444519043
# generated sequence: Will sin by
# Romber'd nesbrery.
#
# Fow IV:
# Leevan hatserve be hamon a forshir,
# Not she hanly, you devent
#
# iter:4499/15000 loss:1.9248093366622925
# generated sequence: Wirg; aly Soun to ine'd pruccosh that mactles a grecked:
# A
# Whese ary like
# D, this I umplave,
# And that
#
# iter:4599/15000 loss:1.8652186393737793
# generated sequence: Way: and with un hering in thy cray, sy to this thou hink fariot: goou's enjus grien, se foie to the
#
# iter:4699/15000 loss:1.9159899950027466
# generated sequence: Was
# To thro'l cllate precbernowlears;
# Theren mul.
#
# DUKE:
# My hopuented kill that my as you adsencioue
#
#
# iter:4799/15000 loss:1.8746932744979858
# generated sequence: We way
# Your come the sill if mary so that
# have deceor them bace is Lord in when hes revan nown. Now t
#
# iter:4899/15000 loss:1.876908540725708
# generated sequence: Whill
# Byon and would joth neelive dee mellith;
# I would's most
#  polesfmold I wo't bath
# A'ss to itsecm
#
# iter:4999/15000 loss:1.8807923793792725
# generated sequence: What be,
# As she in it briats lord, my urainged us pery dembintbrolgedst witter will weet angrerty
# His
#
# iter:5099/15000 loss:1.8820912837982178
# generated sequence: Whit
# en?s:
# But now,
# Sret-ca consingllon thoughid;
# And there it hind is well beto
#
# BAt
# AMIRA:
# Belcowee
#
# iter:5199/15000 loss:1.9208251237869263
# generated sequence: We trees,
# And, he suf
# Wherall' tim pate.
#
# Yet, know, or wimb that chombaikines, hulk I serely me tt h
#
# iter:5299/15000 loss:1.9131486415863037
# generated sequence: Whicae, chaskes, his mad. But of this I chaich
# Wh't mady to she what a valthre;
# Rertita famser's Pely
#
# iter:5399/15000 loss:1.8967435359954834
# generated sequence: When up, then
# mother roven.
#
# HAD LIIN:
# For whens.
#
# LOMERS:
# I to heacen:
# And deary, thy stanst mascim!
#
# iter:5499/15000 loss:1.9113320112228394
# generated sequence: Weres tatees, fay bllaning, roint row:
# Leavely or'lived not hell to ople gracbles; the searbn our rro
#
# iter:5599/15000 loss:1.9457511901855469
# generated sequence: Will Ifear of a sum, not so these of wather coifere lood.
# To Bentrureful, sous the mouess cescals are
#
# iter:5699/15000 loss:1.927567720413208
# generated sequence: Wey thy heart conous as his granig to jooh am Io hot thaul, in the Dierougn
# Asstal whed have seel thr
#
# iter:5799/15000 loss:1.8760570287704468
# generated sequence: Were!
#
# DUKE?:
# Whep tost!'
# I all sthericely nots end as and carting dows,
# Vise sainifes of prince.
#
# HO
#
# iter:5899/15000 loss:1.8833913803100586
# generated sequence: Walden poor! I hear you the lwonsuso the shall droce,
# Reron.
# I sheirmborr not this 'p assing:
# A pours
#
# iter:5999/15000 loss:1.9201323986053467
# generated sequence: Whatght the deagmand so that hald be hone.
#
# DUKENES:
# Senthing you befrage.
#
# HORTENSA:
# No,
# is but.
#
# JU
#
# iter:6099/15000 loss:1.874502420425415
# generated sequence: Werice orleroncy fisedering tlings, though heact no; hir, ling, to clain's
# Trwir!
#
# QUETINCAS:
# Which t
#
# iter:6199/15000 loss:1.8904119729995728
# generated sequence: Who' upord;
# A wordererpe
# Mose wixcopes.
# ol me.
#
# her think pidst otalist it his tht theserng him, here
#
# iter:6299/15000 loss:1.8841825723648071
# generated sequence: Which your mick: I have brain requnress, both I now I who sepplobeed in geaving you, the welt and bru
#
# iter:6399/15000 loss:1.8848000764846802
# generated sequence: Wher oll fauch tell Fas for a les chame.
#
# Bead sey give ony gequne
# And deay nas I vieve to heavencase
#
# iter:6499/15000 loss:1.8487008810043335
# generated sequence: Wisle, I'll--
# ARTISANFO:
# That what be shact tyesf his nlasunt not expays, he and you that the ala; bu
#
# iter:6599/15000 loss:1.8495432138442993
# generated sequence: We Edwild ertusio's
# of this pronse af; and not me?
#
# NIONPES:
# Oo, and mpagle,
# An not in
# Taid his me an
#
# iter:6699/15000 loss:1.8692141771316528
# generated sequence: Who, iffeeres,--
# And to
# Thar out for for uesw be mosterusainock mark, God
# Tham in our leful thou boue
#
# iter:6799/15000 loss:1.8825316429138184
# generated sequence: Wish brei! and,
# Mor him;
# It the farthurk,
# Chate a flewe off beser his d! wayowy deking like Edward's
#
# iter:6899/15000 loss:1.8317660093307495
# generated sequence: We frien.
# Whecemy case ace are proth
# She makisolvos
# My iner;
# Forse, my neyion;
# Wher id Edward in ever
#
# iter:6999/15000 loss:1.8964561223983765
# generated sequence: Weritor llovering way. Masted that wordirge? let: lietaiming tendet Costar?
#
# COMINIUGA:
#
# CAMPHBERd:
# O
#
# iter:7099/15000 loss:1.890123724937439
# generated sequence: What his of gowite tell, his owe prayse.'d his to live onenoun it, sun my foue hap she shall to be th
#
# iter:7199/15000 loss:1.8702501058578491
# generated sequence: WARS:
# Do-deant's as fillace deast mine thun,
# Well that of shald ond you be I his he ad:
#
# ANTIS:
# A grv
#
# iter:7299/15000 loss:1.8790000677108765
# generated sequence: What podded it now shall goon that of Yorts wa liety of more the sund reick by
# Raub
# I and Merrupty el
#
# iter:7399/15000 loss:1.8391408920288086
# generated sequence: Why, aft, mado's lovos digut poirtron:
# I am it thee habe guad!
#
# LEONTES:
# May my beds?
# My eman,
# O bet.
#
# iter:7499/15000 loss:1.8758083581924438
# generated sequence: We pope in did pargiot soched septa
# Dwould weeth ponelances steal!
# I pain thum go thase fain therstra
#
# iter:7599/15000 loss:1.866533637046814
# generated sequence: Wine; what,
# You bested and thou sordernes in.
#
# GLOUCESTER:
# My Lord,
# Wit's nut stenes is beings.
#
# HENR
#
# iter:7699/15000 loss:1.8587795495986938
# generated sequence: Ward be witther: and, assill have is son my speting with;
# Thou son gowexs song,
# The sunone, and with
#
# iter:7799/15000 loss:1.844834804534912
# generated sequence: Whor I tn a me to stull are fareing,
# Ag of her full be vainterness?
#
# SICIUREEBIUS:
# Lar, for oftsent o
#
# iter:7899/15000 loss:1.8137896060943604
# generated sequence: With the we trust to pawt
# Telp the wite.
#
# JULIET:
# Svel: wall fare! that prair from thisom
# Thee,
# To be
#
# iter:7999/15000 loss:1.8141204118728638
# generated sequence: WAShINGWARD IVHARFNCENTIO:
# But and be, own manno:
# So mer, and eleno?
# O hat be mitizer'd mely. Clover
#
#
# iter:8099/15000 loss:1.8551758527755737
# generated sequence: Whan to contonce of. I fook stustery lestricone toom ok the withee:
# But I hath ariot forth the yut be
#
# iter:8199/15000 loss:1.8219387531280518
# generated sequence: Why, what will bus not to and geaple a lays home, the the queeame: which deech, if your shall Gongher
#
# iter:8299/15000 loss:1.8376439809799194
# generated sequence: Which!two betwe will had no:
# A came of mour not usssefft to you now. Now.
#
# LAUDULBER:
# Gosby off ded o
#
# iter:8399/15000 loss:1.829278826713562
# generated sequence: WASPANIIA:
# What Kersmy in alrerch.
#
# NENGY:
# I bry the prisel untald, me have dastist to nave, thy, thi
#
# iter:8499/15000 loss:1.8374648094177246
# generated sequence: We canice and,
# Merethre, what. Let
# thee I pray queathers, Fearl it fue breal, no king's mitem neess t
#
# iter:8599/15000 loss:1.8726705312728882
# generated sequence: Which him ail ster minorf:
# O, wiltany you
# comic usfure well is not not haply bliat to consender till
#
# iter:8699/15000 loss:1.8545981645584106
# generated sequence: Wist mastacus ill ged at fay Butts this Homen: sseer:
# The eifetly worded me majeeed.
#
# Byou to me, now
#
# iter:8799/15000 loss:1.8647431135177612
# generated sequence: We well do art the stade
# 'sing overains for speak:
# Fitset their stopt that is thinilmy!
#
# Thit Romea ,
#
# iter:8899/15000 loss:1.8268731832504272
# generated sequence: WARD HARUY:
# How, of your heal re;erd: as leer, and and by as toemessenter?
#
# SEMNR:
# Myself.
#
# RIVIO:
# It
#
# iter:8999/15000 loss:1.839195966720581
# generated sequence: Wengroo, set alfirs bends:
# For Gown
# Thous upon sheess,
# The oud douesed.
# That werencound besere.
#
# AXII
#
# iter:9099/15000 loss:1.8103989362716675
# generated sequence: What, hibjuy, and the fulry chol a look; the freplibmost. You me
# fill cam; wheed.
#
# Now RIFGROM:
# What
#
# iter:9199/15000 loss:1.863473653793335
# generated sequence: Why, fartured wear boor whereware arm'diolder:
# Farlook'r hume her queton
# I perty and chiltw':
# He's wa
#
# iter:9299/15000 loss:1.798944354057312
# generated sequence: WAy, be my toant that, tor shall'd
# Ap,
# Of;
# Speak, his i'st shove fatcosiee,
# My lord thy
# Bock
# I abent
#
# iter:9399/15000 loss:1.8578249216079712
# generated sequence: WA chowed
# And Condoshar'sear me throph wadelf!
# There trcaunies the stand may! That with my home,
# Whre
#
# iter:9499/15000 loss:1.8564088344573975
# generated sequence: Wer withis herry hape here like with-gon!
# And untless
# The art your go down,
# Unter herods, bires:
# Thy
#
# iter:9599/15000 loss:1.8536990880966187
# generated sequence: Wand:
# Alo-cone a boon down I gead!
# The we'le sua on my secutts's noul of Our fear dank, my our; a hox
#
# iter:9699/15000 loss:1.8276735544204712
# generated sequence: We kind;
# Held faith compfren on you our in allongance corspulce
# O sealt,
# O.
#
# ERWARD:
# Nop you's eye wo
#
# iter:9799/15000 loss:1.8154196739196777
# generated sequence: WARDO:
# What you was my Raress
# Mare thoughd;
# Whoss this upon is my sinut keask?
#
# BUCKENG HENRUSHARO DO
#
# iter:9899/15000 loss:1.8756487369537354
# generated sequence: Where
# the but I will tell devich ent at hers to hinquer:
# I plead may?
#
# JULIES:
# I say, in or they as m
#
# iter:9999/15000 loss:1.8275938034057617
# generated sequence: What doll;
# And.
#
# SAMards downich drettens to rempects be ollo slling:
# Lordnely toases 'Abe.
#
# SAMILINs
#
# iter:10099/15000 loss:1.8604705333709717
# generated sequence: Which with has hhand:
# And ding in a lord in thus mispate ableate.
#
# First E bruuet, that Partiz; that
#
# iter:10199/15000 loss:1.8503973484039307
# generated sequence: Who poigtd to a poinn rofast?
#
# PETRUCHIRG:
# A prear's poir; Agare's you potemeif. O fory now faing, I
#
# iter:10299/15000 loss:1.8222713470458984
# generated sequence: Whea this my mour.
#
# LORES:
# For'd thou witten it pay, what Rome me heam! Of a dehs
# Whice on you you do
#
# iter:10399/15000 loss:1.839548945426941
# generated sequence: We could by in tour sll! if.
# Tyes my hearth hald curs nried just child wosh a caiqing,, I pripf; me,
#
# iter:10499/15000 loss:1.8560388088226318
# generated sequence: Whom he har come scoppoies excice in the read ass of Shalffole ane one should coundis, if Geave I sha
#
# iter:10599/15000 loss:1.8317582607269287
# generated sequence: Who thyeglousingweet
# Telt, hurder bay; beat,
# Meatienly, wheen'd that the hatple so king eyes tore a q
#
# iter:10699/15000 loss:1.8092445135116577
# generated sequence: Where withous eyom to wertary theirs;
# To exear lone sord warn wilr the firself, and in horthet:
# With.
#
# iter:10799/15000 loss:1.8026551008224487
# generated sequence: What me: for ever praynd; there heal!
#
# PIFFr.:
# Se!
# And in,--
# thee can for I the king
# Po,
# Our fase, by
#
# iter:10899/15000 loss:1.8021665811538696
# generated sequence: Whim lims this.
#
# FlANTIA:
# Are prom:
# oul he lova take?
# I kert teart in EIss erd hownot,
# Is ell.
# To him
#
# iter:10999/15000 loss:1.8346264362335205
# generated sequence: Wish bods.
# Cum a-'dry, I. Har weem, bet morl?
#
# RDASEY:
# Isem frie timer forgens,
# He grazel art Than hi
#
# iter:11099/15000 loss:1.8181891441345215
# generated sequence: Who bepon' in her sign erpicts not, moraloustaltirgd, Goll in be thouse to grees, I wishaut byous.
#
# C
#
# iter:11199/15000 loss:1.8088016510009766
# generated sequence: Wing bod?
#
# Batt my wone, I fat of othy string.
#
# LADY BOLFRY VI': in ase my the mine my lies,
# And fula
#
# iter:11299/15000 loss:1.8123791217803955
# generated sequence: Wery apt fill in that wells
# I was be it
# wenced.
# What laddent.
#
# DUKE VINE:
# Uvanfless to quifel shall f
#
# iter:11399/15000 loss:1.769614577293396
# generated sequence: Whichsears:
# Whanks of thee we bewion comfort in every,'s ha liess.
#
# NONTOLIO:
# Kesain upon you these p
#
# iter:11499/15000 loss:1.8078988790512085
# generated sequence: What sicless.--grame
# But must andust the quick as the place stenedseread not he! the most thee dipunt
#
# iter:11599/15000 loss:1.8289958238601685
# generated sequence: When and heal in knot me sait liod file osstten.
#
# GLOUCESTER:
# Which, before yourselter tour fromit to
#
# iter:11699/15000 loss:1.8246296644210815
# generated sequence: Which, which:
# 'tances, 'tme me and herdely.
# Trum?
# Why's free:
# I lo; therefor as actale's not
# so.
# This
#
# iter:11799/15000 loss:1.8264498710632324
# generated sequence: Wich Jucknesdesed the herselister.
#
# MENENIUS:
# Wastrit's wrongts,
# Thy isspeely cheny undien.
#
# Firgh de
#
# iter:11899/15000 loss:1.7865275144577026
# generated sequence: Wilk begices.
# But an flely Letten.
# But of bayon ttear Lord?
# And seal her waether's kipply for failm,
#
# iter:11999/15000 loss:1.835410714149475
# generated sequence: WArd.
# All the puccrantagn thibjelled for the dickuron? Why, some, better
# I not nade. Whents;
# I so the
#
# iter:12099/15000 loss:1.8469399213790894
# generated sequence: What her breat for prangerbantion, brook there prochey steat came you beant, nown what his lomkow the
#
# iter:12199/15000 loss:1.8227171897888184
# generated sequence: With in Honous no mernks,
# And not from her.
# God where couse,
# To do awmere ow stould feplouchs.
#
# ANGAR
#
# iter:12299/15000 loss:1.8048133850097656
# generated sequence: Which re all
# Ithen then how all: this hander'st mead up in Itirldshabs, herehtace, supulst cases mare
#
# iter:12399/15000 loss:1.801602840423584
# generated sequence: Why know of malstise braines slaunt werr'st his,
# I of vause.
# For word:
# And shall prise geverse a pray
#
# iter:12499/15000 loss:1.818379282951355
# generated sequence: Where lo geace the Fiste and no swishge man fletion me?
#
# GLONIO:
# Whilt meping my
# Eose divate, it natl
#
# iter:12599/15000 loss:1.7853730916976929
# generated sequence: WARDICA:
# That man lelk;
# Chap
# there are did thought many.
# Fours man can comen me antray, sir lecain: a
#
# iter:12699/15000 loss:1.8037687540054321
# generated sequence: Wience.
#
# SEBASTIAN:
# Well am the you;
# And nabeed.
#
# PRIAN:
# Walfep
# Thoughds
# And frill fay; and they wher
#
# iter:12799/15000 loss:1.8452742099761963
# generated sequence: Wher thereto  I
# And give, at on I have thy foulo to have the lack'd well whos thee my laims the day a
#
# iter:12899/15000 loss:1.8194185495376587
# generated sequence: WA Folds so leldst
# Wer of triy? many
# for the high so colat tensent thy dearsed
# My
# UK:
# You, come fortu
#
# iter:12999/15000 loss:1.8176755905151367
# generated sequence: We them
# The mend affeak the son.
#
# PAMPSET:
# I damt
# Tell in your crumbed of daugh med a knight; amazed
#
# iter:13099/15000 loss:1.7931205034255981
# generated sequence: Will.
# A from I marrer worth no; to her the forth him lase More the distertt;
# Where you matest woons m
#
# iter:13199/15000 loss:1.785561442375183
# generated sequence: WANDEd:
# I quar hate of hand war a longed but honce if a hust was you hath
# and a pely.
#
# NLORK:
# The all
#
# iter:13299/15000 loss:1.8160533905029297
# generated sequence: Wn aid and brain ressuenty.
#
# ALLANIO:
# He gales; and the more of my lord,
# Whe.
#
# LAUND: Lyou ist inamat
#
# iter:13399/15000 loss:1.8090322017669678
# generated sequence: Whou spuchl tretars broth:
# Fe'dly
# blood injust:,
# And kior our Mofferd have airs his hean my lord.
#
# No
#
# iter:13499/15000 loss:1.7949453592300415
# generated sequence: We her miggnourgiod till nom mungs me; where! I have home.
#
# PUCII:
# Ho haughinggnea; use, whiles; bett
#
# iter:13599/15000 loss:1.8393093347549438
# generated sequence: What me amand undig-ray, and
# iuss but it. I penturus,
# Or antwry! dictly offears
# Of Fontue can-tly Dig
#
# iter:13699/15000 loss:1.828873872756958
# generated sequence: WAScound.
#
# KING EDWARD IVABELL:
# My scome.
#
# DUARELYCUM:
# He'll the sirve swelasure yeild no foule; our
#
# iter:13799/15000 loss:1.7882381677627563
# generated sequence: Weet eastersfis grovieg:
# Swishase tam, the caust:
# And the ol, brait wor, strat,
# And Olad our hengener
#
# iter:13899/15000 loss:1.829609751701355
# generated sequence: WARTh:
# For Ralest to gyter my deads.
# The 'ot me the jude tottred, here of hath a quick, and bod
# Godd
#
# iter:13999/15000 loss:1.7981164455413818
# generated sequence: Why hears,
# As arforar and herick, libe intupe, mud too, and your takes us my aadss of
# T,
# Litter mat c
#
# iter:14099/15000 loss:1.782492756843567
# generated sequence: Whim.
#
# CLARENCE:
# Which om tope place wise of thou way
# Thou art thou to so queeofs in ofteds'd, took h
#
# iter:14199/15000 loss:1.8121100664138794
# generated sequence: Why ulaud farch for masegued.
#
# DUKE VILIRO:
# I have my speak Sights arsmy, joy, if no, I was very once
#
# iter:14299/15000 loss:1.7999157905578613
# generated sequence: What you whad liods
# A gangef, I will bocksire me we: herrialinion my soning; good,
# I ladly.
#
# ESRIO:
# A
#
# iter:14399/15000 loss:1.784548044204712
# generated sequence: Whan living; she with awn artwice hive stbunous, and but houre, anawarld let'tsolde.
# Durged heartick
#
# iter:14499/15000 loss:1.802498459815979
# generated sequence: Which like that his heraus vangers
# Thus saug.
#
# LADUK:
# Of doinet besife. Yet me, my buck,
# Sur lose, Te
#
# iter:14599/15000 loss:1.806761384010315
# generated sequence: Whap reven is we me. Let be holy how she, this next so rith modid wither what wrofos's ustand.
#
# PROST
#
# iter:14699/15000 loss:1.8185065984725952
# generated sequence: Will reft bind.
#
# MENENIUS:
# Shall noble it were alothilvon of it forbin
# were bod failt of that
# is the
#
# iter:14799/15000 loss:1.8021231889724731
# generated sequence: Wilcess: for you mo his Loins the lefbramph lady goblifed the mbjer'd say redeman she cruds we shear
#
# iter:14899/15000 loss:1.832942008972168
# generated sequence: WAR! II:
# Fo; sork one it one.
#
# Fichise.
#
# FrrAD:
# To stmementand him;
# Enten, oo,
# As I me him? that ilot
#
# iter:14999/15000 loss:1.7918158769607544
# generated sequence: What, sornt.
#
# BITHANTES:
#
# MARIGLS:
# So;
# And the nevencare me prampp,
# The never was me,
# Ther, will of m

# %% [markdown]
# #### Training Loss Curve

# %%
plt.xlabel('iters')
plt.ylabel('loss')
plt.plot(all_losses)
plt.show()

# %% [markdown]
# #### Evaluation: A Sample of Generated Sequence

# %%
print(eval_step(net, predicted_len=600))
# Out:
# What I niares, protals, Loff let hear prarh our mebssilly in brok not at this pretroth may tlaadlen, but a obouse.
#
# First Clord:
# That me?
#
# ISABERLAND:
# AXd for cank uphish them that fir plute
# Have you are conch me or mas best so, hear aratters stauntisty slady leftury.
#
# Agonot swemples,
# As news.
#
# HENRY Le:
# 'That of saysed-'sindechald and or nebs as I case or soar,
# But thus have illainger'd man your my master make's ongee anchiss's this morse nobrave
# That shall do a will from sorfor prattart,
# As myself o? Whine.
# Offams of Goos wack, 'tworr:
# Sirced,
# Ane she
# Comfils danger,'t the warth, morry, 'sop
